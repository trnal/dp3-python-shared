# %% [markdown]
# # Script to generate binary masks of each cell-type
# # Created by Ruchika Verma
#
# This code will create separate folder for each patient and subfolders for annotated images under each patient's folder.
#
# Each sub-folder corresponding to sub-images under each patient will contain 4 sub-sub-folders (Epithelial, Lymphocyte, Neutrophil and Macrophage) to save their corresponding binary-masks with value 255 for each cell-type and background 0
#
# # Input
# data_path: Specify the path of downloaded images
#
# destination_path = Specify the path to save corresponding binary masks
#
# # Output
# MoNuSAC_masks directory in the destination_path
#
# Binary masks will be saved in each sub-sub-folder
#
# Folder -- Patient name
#
# Sub-folder -- Sub-images under each patient
#
# Sub-Sub-folder -- Annotated cell-type on each sub-image

# %%
import sys
sys.path.append('/')
from config import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-e074ecd48ee4> in <module>
#       1 import sys
#       2 sys.path.append('/')
# ----> 3 from config import *
#
# ModuleNotFoundError: No module named 'config'

# %%
#Process whole slide images
import os
import openslide
from xml.dom import minidom
import numpy as np
import openslide
from openslide import open_slide  
from glob import glob
import cv2
import matplotlib.pyplot as plt
import scipy.io as sio
from PIL import Image
import scipy
import scipy.ndimage
from shapely.geometry import Polygon
from skimage import draw
import xml.etree.ElementTree as ET

# %%
# Read svs files from the desired path
count = 0
data_path = MONUSAC_DATA #Path to read data from
destination_path = MONUSAC_FOLDER.rstrip('/') # Path to save binary masks corresponding to xml files
os.chdir(destination_path)

try:
    os.mkdir(destination_path+'/MoNuSAC_masks')
except OSError:
    print ("Creation of the mask directory %s failed" % destination_path)
    
os.chdir(destination_path+'/MoNuSAC_masks')#Create folder named as MoNuSAC_masks
patients = [x[0] for x in os.walk(data_path)]#Total patients in the data_path
if data_path in patients: patients.remove(data_path)
len(patients)
# Out:
# 46

# %%
full_dest_path = destination_path + '/MoNuSAC_masks/'

# %%
for patient_loc in patients[1:]:
    patient_name = patient_loc[len(data_path)+1:]#Patient name
    print(patient_name)
        
    ## To make patient's name directory in the destination folder
    try:
        os.mkdir(full_dest_path + patient_name)
    except OSError:
        print ("\n Creation of the patient's directory %s failed" % patient_name)
        
    ## Read sub-images of each patient in the data path        
    sub_images = glob(patient_loc+'/*.svs')
    for sub_image_loc in sub_images:
        sub_image_name = sub_image_loc[len(data_path)+len(patient_name)+1:-4]        
        print(sub_image_name)
        
        ## To make sub_image directory under the patient's folder
        sub_image = full_dest_path + patient_name+'/'+sub_image_name #Destination path
        try:
            os.mkdir(sub_image)
        except OSError:
            print ("\n Creation of the patient's directory %s failed" % sub_image)
            
        image_name = sub_image_loc
        img = openslide.OpenSlide(image_name)
                                  
        # If svs image needs to save in tif
        cv2.imwrite(sub_image_loc[:-4]+'.tif', np.array(img.read_region((0,0),0,img.level_dimensions[0])))      
   
        # Read xml file
        xml_file_name  = image_name[:-4]
        xml_file_name = xml_file_name+'.xml'
        tree = ET.parse(xml_file_name)
        root = tree.getroot()
        
        #Generate binary mask for each cell-type                         
        for k in range(len(root)):
            label = [x.attrib['Name'] for x in root[k][0]]
            label = label[0]
            
            for child in root[k]:
                for x in child:
                    r = x.tag
                    if r == 'Attribute':
                        count = count+1
                        print(count)
                        label = x.attrib['Name']
                        binary_mask = np.transpose(np.zeros((img.read_region((0,0),0,img.level_dimensions[0]).size), dtype='uint8')) 
                        print(label)
                        
                        # Create directory for each label
                        sub_path = sub_image+'/'+label
                        
                        try:
                            os.mkdir(sub_path)
                        except OSError:
                            print ("Creation of the directory %s failed" % label)
                        else:
                            print ("Successfully created the directory %s " % label) 
                                          
                        
                    if r == 'Region':
                        regions = []
                        vertices = x[1]
                        coords = np.zeros((len(vertices), 2))
                        for i, vertex in enumerate(vertices):
                            coords[i][0] = vertex.attrib['X']
                            coords[i][1] = vertex.attrib['Y']        
                        regions.append(coords)
                        poly = Polygon(regions[0])  
                        
                        vertex_row_coords = regions[0][:,0]
                        vertex_col_coords = regions[0][:,1]
                        fill_row_coords, fill_col_coords = draw.polygon(vertex_col_coords, vertex_row_coords, binary_mask.shape)
                        binary_mask[fill_row_coords, fill_col_coords] = 255
                        mask_path = sub_path+'/'+str(count)+'_mask.tif'
                        cv2.imwrite(mask_path, binary_mask)
# Out:
# TCGA-55-1594-01Z-00-DX1
# /TCGA-55-1594-01Z-00-DX1_005
# 17
# Epithelial
# Successfully created the directory Epithelial
# 18
# Lymphocyte
# Successfully created the directory Lymphocyte
# 19
# Neutrophil
# Successfully created the directory Neutrophil
# 20
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-55-1594-01Z-00-DX1_004
# 21
# Epithelial
# Successfully created the directory Epithelial
# 22
# Lymphocyte
# Successfully created the directory Lymphocyte
# 23
# Neutrophil
# Successfully created the directory Neutrophil
# 24
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-55-1594-01Z-00-DX1_001
# 25
# Epithelial
# Successfully created the directory Epithelial
# 26
# Lymphocyte
# Successfully created the directory Lymphocyte
# 27
# Neutrophil
# Successfully created the directory Neutrophil
# 28
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-55-1594-01Z-00-DX1_003
# 29
# Epithelial
# Successfully created the directory Epithelial
# 30
# Lymphocyte
# Successfully created the directory Lymphocyte
# 31
# Neutrophil
# Successfully created the directory Neutrophil
# 32
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-55-1594-01Z-00-DX1_002
# 33
# Epithelial
# Successfully created the directory Epithelial
# 34
# Lymphocyte
# Successfully created the directory Lymphocyte
# 35
# Neutrophil
# Successfully created the directory Neutrophil
# 36
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EV-5903-01Z-00-DX1
# /TCGA-EV-5903-01Z-00-DX1_4
# 37
# Epithelial
# Successfully created the directory Epithelial
# 38
# Lymphocyte
# Successfully created the directory Lymphocyte
# 39
# Neutrophil
# Successfully created the directory Neutrophil
# 40
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EV-5903-01Z-00-DX1_5
# 41
# Epithelial
# Successfully created the directory Epithelial
# 42
# Lymphocyte
# Successfully created the directory Lymphocyte
# 43
# Neutrophil
# Successfully created the directory Neutrophil
# 44
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EV-5903-01Z-00-DX1_1
# 45
# Epithelial
# Successfully created the directory Epithelial
# 46
# Lymphocyte
# Successfully created the directory Lymphocyte
# 47
# Neutrophil
# Successfully created the directory Neutrophil
# 48
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EV-5903-01Z-00-DX1_2
# 49
# Epithelial
# Successfully created the directory Epithelial
# 50
# Lymphocyte
# Successfully created the directory Lymphocyte
# 51
# Neutrophil
# Successfully created the directory Neutrophil
# 52
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EV-5903-01Z-00-DX1_3
# 53
# Epithelial
# Successfully created the directory Epithelial
# 54
# Lymphocyte
# Successfully created the directory Lymphocyte
# 55
# Neutrophil
# Successfully created the directory Neutrophil
# 56
# Macrophage
# Successfully created the directory Macrophage
# TCGA-YL-A9WY-01Z-00-DX1
# /TCGA-YL-A9WY-01Z-00-DX1-4
# 57
# Epithelial
# Successfully created the directory Epithelial
# 58
# Lymphocyte
# Successfully created the directory Lymphocyte
# 59
# Neutrophil
# Successfully created the directory Neutrophil
# 60
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-YL-A9WY-01Z-00-DX1-5
# 61
# Epithelial
# Successfully created the directory Epithelial
# 62
# Lymphocyte
# Successfully created the directory Lymphocyte
# 63
# Neutrophil
# Successfully created the directory Neutrophil
# 64
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-YL-A9WY-01Z-00-DX1-1
# 65
# Epithelial
# Successfully created the directory Epithelial
# 66
# Lymphocyte
# Successfully created the directory Lymphocyte
# 67
# Neutrophil
# Successfully created the directory Neutrophil
# 68
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-YL-A9WY-01Z-00-DX1-2
# 69
# Epithelial
# Successfully created the directory Epithelial
# 70
# Lymphocyte
# Successfully created the directory Lymphocyte
# 71
# Neutrophil
# Successfully created the directory Neutrophil
# 72
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-YL-A9WY-01Z-00-DX1-3
# 73
# Epithelial
# Successfully created the directory Epithelial
# 74
# Lymphocyte
# Successfully created the directory Lymphocyte
# 75
# Neutrophil
# Successfully created the directory Neutrophil
# 76
# Macrophage
# Successfully created the directory Macrophage
# TCGA-A2-A0ES-01Z-00-DX1
# /TCGA-A2-A0ES-01Z-00-DX1_4
# 77
# Epithelial
# Successfully created the directory Epithelial
# 78
# Lymphocyte
# Successfully created the directory Lymphocyte
# 79
# Neutrophil
# Successfully created the directory Neutrophil
# 80
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0ES-01Z-00-DX1_5
# 81
# Epithelial
# Successfully created the directory Epithelial
# 82
# Lymphocyte
# Successfully created the directory Lymphocyte
# 83
# Neutrophil
# Successfully created the directory Neutrophil
# 84
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0ES-01Z-00-DX1_2
# 85
# Epithelial
# Successfully created the directory Epithelial
# 86
# Lymphocyte
# Successfully created the directory Lymphocyte
# 87
# Neutrophil
# Successfully created the directory Neutrophil
# 88
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0ES-01Z-00-DX1_3
# 89
# Epithelial
# Successfully created the directory Epithelial
# 90
# Lymphocyte
# Successfully created the directory Lymphocyte
# 91
# Neutrophil
# Successfully created the directory Neutrophil
# 92
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0ES-01Z-00-DX1_1
# 93
# Epithelial
# Successfully created the directory Epithelial
# 94
# Lymphocyte
# Successfully created the directory Lymphocyte
# 95
# Neutrophil
# Successfully created the directory Neutrophil
# 96
# Macrophage
# Successfully created the directory Macrophage
# TCGA-DW-7841-01Z-00-DX1
# /TCGA-DW-7841-01Z-00-DX1_3
# 97
# Epithelial
# Successfully created the directory Epithelial
# 98
# Lymphocyte
# Successfully created the directory Lymphocyte
# 99
# Neutrophil
# Successfully created the directory Neutrophil
# 100
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-DW-7841-01Z-00-DX1_2
# 101
# Epithelial
# Successfully created the directory Epithelial
# 102
# Lymphocyte
# Successfully created the directory Lymphocyte
# 103
# Neutrophil
# Successfully created the directory Neutrophil
# 104
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-DW-7841-01Z-00-DX1_1
# 105
# Epithelial
# Successfully created the directory Epithelial
# 106
# Lymphocyte
# Successfully created the directory Lymphocyte
# 107
# Neutrophil
# Successfully created the directory Neutrophil
# 108
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A6E0-01Z-00-DX1
# /TCGA-KK-A6E0-01Z-00-DX1-4
# 109
# Epithelial
# Successfully created the directory Epithelial
# 110
# Lymphocyte
# Successfully created the directory Lymphocyte
# 111
# Neutrophil
# Successfully created the directory Neutrophil
# 112
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A6E0-01Z-00-DX1-5
# 113
# Epithelial
# Successfully created the directory Epithelial
# 114
# Lymphocyte
# Successfully created the directory Lymphocyte
# 115
# Neutrophil
# Successfully created the directory Neutrophil
# 116
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A6E0-01Z-00-DX1-2
# 117
# Epithelial
# Successfully created the directory Epithelial
# 118
# Lymphocyte
# Successfully created the directory Lymphocyte
# 119
# Neutrophil
# Successfully created the directory Neutrophil
# 120
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A6E0-01Z-00-DX1-3
# 121
# Epithelial
# Successfully created the directory Epithelial
# 122
# Lymphocyte
# Successfully created the directory Lymphocyte
# 123
# Neutrophil
# Successfully created the directory Neutrophil
# 124
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A6E0-01Z-00-DX1-1
# 125
# Epithelial
# Successfully created the directory Epithelial
# 126
# Lymphocyte
# Successfully created the directory Lymphocyte
# 127
# Neutrophil
# Successfully created the directory Neutrophil
# 128
# Macrophage
# Successfully created the directory Macrophage
# TCGA-UZ-A9PU-01Z-00-DX1
# /TCGA-UZ-A9PU-01Z-00-DX1_2
# 129
# Epithelial
# Successfully created the directory Epithelial
# 130
# Lymphocyte
# Successfully created the directory Lymphocyte
# 131
# Neutrophil
# Successfully created the directory Neutrophil
# 132
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PU-01Z-00-DX1_1
# 133
# Epithelial
# Successfully created the directory Epithelial
# 134
# Lymphocyte
# Successfully created the directory Lymphocyte
# 135
# Neutrophil
# Successfully created the directory Neutrophil
# 136
# Macrophage
# Successfully created the directory Macrophage
# TCGA-B9-A8YI-01Z-00-DX1
# /TCGA-B9-A8YI-01Z-00-DX1_1
# 137
# Epithelial
# Successfully created the directory Epithelial
# 138
# Lymphocyte
# Successfully created the directory Lymphocyte
# 139
# Neutrophil
# Successfully created the directory Neutrophil
# 140
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A8YI-01Z-00-DX1_3
# 141
# Epithelial
# Successfully created the directory Epithelial
# 142
# Lymphocyte
# Successfully created the directory Lymphocyte
# 143
# Neutrophil
# Successfully created the directory Neutrophil
# 144
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A8YI-01Z-00-DX1_2
# 145
# Epithelial
# Successfully created the directory Epithelial
# 146
# Lymphocyte
# Successfully created the directory Lymphocyte
# 147
# Neutrophil
# Successfully created the directory Neutrophil
# 148
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A8YI-01Z-00-DX1_5
# 149
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A8YI-01Z-00-DX1_4
# 150
# Neutrophil
# Successfully created the directory Neutrophil
# TCGA-D8-A1X5-01Z-00-DX2
# /TCGA-D8-A1X5-01Z-00-DX2_4
# 151
# Epithelial
# Successfully created the directory Epithelial
# 152
# Lymphocyte
# Successfully created the directory Lymphocyte
# 153
# Description
# Successfully created the directory Description
# 154
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-D8-A1X5-01Z-00-DX2_1
# 155
# Epithelial
# Successfully created the directory Epithelial
# 156
# Lymphocyte
# Successfully created the directory Lymphocyte
# 157
# Neutrophil
# Successfully created the directory Neutrophil
# 158
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-D8-A1X5-01Z-00-DX2_2
# 159
# Epithelial
# Successfully created the directory Epithelial
# 160
# Lymphocyte
# Successfully created the directory Lymphocyte
# 161
# Neutrophil
# Successfully created the directory Neutrophil
# 162
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-D8-A1X5-01Z-00-DX2_3
# 163
# Epithelial
# Successfully created the directory Epithelial
# 164
# Lymphocyte
# Successfully created the directory Lymphocyte
# 165
# Neutrophil
# Successfully created the directory Neutrophil
# 166
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EJ-5517-01Z-00-DX1
# /TCGA-EJ-5517-01Z-00-DX1-2
# 167
# Neutrophil
# Successfully created the directory Neutrophil
# /TCGA-EJ-5517-01Z-00-DX1-3
# 168
# Neutrophil
# Successfully created the directory Neutrophil
# /TCGA-EJ-5517-01Z-00-DX1-1
# 169
# Neutrophil
# Successfully created the directory Neutrophil
# 170
# Epithelial
# Successfully created the directory Epithelial
# 171
# Lymphocyte
# Successfully created the directory Lymphocyte
# /TCGA-EJ-5517-01Z-00-DX1-4
# 172
# Epithelial
# Successfully created the directory Epithelial
# 173
# Lymphocyte
# Successfully created the directory Lymphocyte
# 174
# Neutrophil
# Successfully created the directory Neutrophil
# TCGA-J4-A67Q-01Z-00-DX1
# /TCGA-J4-A67Q-01Z-00-DX1-2
# 175
# Epithelial
# Successfully created the directory Epithelial
# 176
# Lymphocyte
# Successfully created the directory Lymphocyte
# 177
# Neutrophil
# Successfully created the directory Neutrophil
# 178
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67Q-01Z-00-DX1-3
# 179
# Epithelial
# Successfully created the directory Epithelial
# 180
# Lymphocyte
# Successfully created the directory Lymphocyte
# 181
# Neutrophil
# Successfully created the directory Neutrophil
# 182
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67Q-01Z-00-DX1-1
# 183
# Epithelial
# Successfully created the directory Epithelial
# 184
# Lymphocyte
# Successfully created the directory Lymphocyte
# 185
# Neutrophil
# Successfully created the directory Neutrophil
# 186
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67Q-01Z-00-DX1-4
# 187
# Epithelial
# Successfully created the directory Epithelial
# 188
# Lymphocyte
# Successfully created the directory Lymphocyte
# 189
# Neutrophil
# Successfully created the directory Neutrophil
# 190
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67Q-01Z-00-DX1-5
# 191
# Epithelial
# Successfully created the directory Epithelial
# 192
# Lymphocyte
# Successfully created the directory Lymphocyte
# 193
# Neutrophil
# Successfully created the directory Neutrophil
# 194
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EW-A6SD-01Z-00-DX1
# /TCGA-EW-A6SD-01Z-00-DX1_2
# 195
# Epithelial
# Successfully created the directory Epithelial
# 196
# Lymphocyte
# Successfully created the directory Lymphocyte
# 197
# Neutrophil
# Successfully created the directory Neutrophil
# 198
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EW-A6SD-01Z-00-DX1_3
# 199
# Epithelial
# Successfully created the directory Epithelial
# 200
# Lymphocyte
# Successfully created the directory Lymphocyte
# 201
# Neutrophil
# Successfully created the directory Neutrophil
# 202
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EW-A6SD-01Z-00-DX1_1
# 203
# Epithelial
# Successfully created the directory Epithelial
# 204
# Lymphocyte
# Successfully created the directory Lymphocyte
# 205
# Neutrophil
# Successfully created the directory Neutrophil
# 206
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EW-A6SD-01Z-00-DX1_4
# 207
# Epithelial
# Successfully created the directory Epithelial
# 208
# Lymphocyte
# Successfully created the directory Lymphocyte
# 209
# Neutrophil
# Successfully created the directory Neutrophil
# 210
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EW-A6SD-01Z-00-DX1_5
# 211
# Epithelial
# Successfully created the directory Epithelial
# 212
# Lymphocyte
# Successfully created the directory Lymphocyte
# 213
# Neutrophil
# Successfully created the directory Neutrophil
# 214
# Macrophage
# Successfully created the directory Macrophage
# TCGA-E9-A22B-01Z-00-DX1
# /TCGA-E9-A22B-01Z-00-DX1_3
# 215
# Epithelial
# Successfully created the directory Epithelial
# 216
# Lymphocyte
# Successfully created the directory Lymphocyte
# 217
# Neutrophil
# Successfully created the directory Neutrophil
# 218
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_2
# 219
# Epithelial
# Successfully created the directory Epithelial
# 220
# Lymphocyte
# Successfully created the directory Lymphocyte
# 221
# Neutrophil
# Successfully created the directory Neutrophil
# 222
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_1
# 223
# Epithelial
# Successfully created the directory Epithelial
# 224
# Lymphocyte
# Successfully created the directory Lymphocyte
# 225
# Neutrophil
# Successfully created the directory Neutrophil
# 226
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_5
# 227
# Epithelial
# Successfully created the directory Epithelial
# 228
# Lymphocyte
# Successfully created the directory Lymphocyte
# 229
# Neutrophil
# Successfully created the directory Neutrophil
# 230
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_4
# 231
# Epithelial
# Successfully created the directory Epithelial
# 232
# Lymphocyte
# Successfully created the directory Lymphocyte
# 233
# Neutrophil
# Successfully created the directory Neutrophil
# 234
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_6
# 235
# Epithelial
# Successfully created the directory Epithelial
# 236
# Lymphocyte
# Successfully created the directory Lymphocyte
# 237
# Neutrophil
# Successfully created the directory Neutrophil
# 238
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_7
# 239
# Epithelial
# Successfully created the directory Epithelial
# 240
# Lymphocyte
# Successfully created the directory Lymphocyte
# 241
# Neutrophil
# Successfully created the directory Neutrophil
# 242
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22B-01Z-00-DX1_8
# 243
# Epithelial
# Successfully created the directory Epithelial
# 244
# Lymphocyte
# Successfully created the directory Lymphocyte
# 245
# Neutrophil
# Successfully created the directory Neutrophil
# 246
# Macrophage
# Successfully created the directory Macrophage
# TCGA-G7-A8LD-01Z-00-DX1
# /TCGA-G7-A8LD-01Z-00-DX1_4
# 247
# Epithelial
# Successfully created the directory Epithelial
# 248
# Lymphocyte
# Successfully created the directory Lymphocyte
# 249
# Neutrophil
# Successfully created the directory Neutrophil
# 250
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_5
# 251
# Epithelial
# Successfully created the directory Epithelial
# 252
# Lymphocyte
# Successfully created the directory Lymphocyte
# 253
# Neutrophil
# Successfully created the directory Neutrophil
# 254
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_7
# 255
# Epithelial
# Successfully created the directory Epithelial
# 256
# Lymphocyte
# Successfully created the directory Lymphocyte
# 257
# Neutrophil
# Successfully created the directory Neutrophil
# 258
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_6
# 259
# Epithelial
# Successfully created the directory Epithelial
# 260
# Lymphocyte
# Successfully created the directory Lymphocyte
# 261
# Neutrophil
# Successfully created the directory Neutrophil
# 262
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_2
# 263
# Epithelial
# Successfully created the directory Epithelial
# 264
# Lymphocyte
# Successfully created the directory Lymphocyte
# 265
# Neutrophil
# Successfully created the directory Neutrophil
# 266
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_3
# 267
# Epithelial
# Successfully created the directory Epithelial
# 268
# Lymphocyte
# Successfully created the directory Lymphocyte
# 269
# Neutrophil
# Successfully created the directory Neutrophil
# 270
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_1
# 271
# Epithelial
# Successfully created the directory Epithelial
# 272
# Lymphocyte
# Successfully created the directory Lymphocyte
# 273
# Neutrophil
# Successfully created the directory Neutrophil
# 274
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_10
# 275
# Epithelial
# Successfully created the directory Epithelial
# 276
# Lymphocyte
# Successfully created the directory Lymphocyte
# 277
# Neutrophil
# Successfully created the directory Neutrophil
# 278
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_8
# 279
# Epithelial
# Successfully created the directory Epithelial
# 280
# Lymphocyte
# Successfully created the directory Lymphocyte
# 281
# Neutrophil
# Successfully created the directory Neutrophil
# 282
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G7-A8LD-01Z-00-DX1_9
# 283
# Epithelial
# Successfully created the directory Epithelial
# 284
# Lymphocyte
# Successfully created the directory Lymphocyte
# 285
# Neutrophil
# Successfully created the directory Neutrophil
# 286
# Macrophage
# Successfully created the directory Macrophage
# TCGA-B6-A0WZ-01Z-00-DX1
# /TCGA-B6-A0WZ-01Z-00-DX1_4
# 287
# Epithelial
# Successfully created the directory Epithelial
# 288
# Lymphocyte
# Successfully created the directory Lymphocyte
# 289
# Neutrophil
# Successfully created the directory Neutrophil
# 290
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B6-A0WZ-01Z-00-DX1_5
# 291
# Epithelial
# Successfully created the directory Epithelial
# 292
# Lymphocyte
# Successfully created the directory Lymphocyte
# 293
# Neutrophil
# Successfully created the directory Neutrophil
# 294
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B6-A0WZ-01Z-00-DX1_6
# 295
# Epithelial
# Successfully created the directory Epithelial
# 296
# Lymphocyte
# Successfully created the directory Lymphocyte
# 297
# Neutrophil
# Successfully created the directory Neutrophil
# 298
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B6-A0WZ-01Z-00-DX1_2
# 299
# Epithelial
# Successfully created the directory Epithelial
# 300
# Lymphocyte
# Successfully created the directory Lymphocyte
# 301
# Neutrophil
# Successfully created the directory Neutrophil
# 302
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B6-A0WZ-01Z-00-DX1_3
# 303
# Epithelial
# Successfully created the directory Epithelial
# 304
# Lymphocyte
# Successfully created the directory Lymphocyte
# 305
# Neutrophil
# Successfully created the directory Neutrophil
# 306
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B6-A0WZ-01Z-00-DX1_1
# 307
# Epithelial
# Successfully created the directory Epithelial
# 308
# Lymphocyte
# Successfully created the directory Lymphocyte
# 309
# Neutrophil
# Successfully created the directory Neutrophil
# 310
# Macrophage
# Successfully created the directory Macrophage
# TCGA-E9-A22G-01Z-00-DX1
# /TCGA-E9-A22G-01Z-00-DX1_5
# 311
# Epithelial
# Successfully created the directory Epithelial
# 312
# Lymphocyte
# Successfully created the directory Lymphocyte
# 313
# Neutrophil
# Successfully created the directory Neutrophil
# 314
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22G-01Z-00-DX1_4
# 315
# Epithelial
# Successfully created the directory Epithelial
# 316
# Lymphocyte
# Successfully created the directory Lymphocyte
# 317
# Neutrophil
# Successfully created the directory Neutrophil
# 318
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22G-01Z-00-DX1_1
# 319
# Epithelial
# Successfully created the directory Epithelial
# 320
# Lymphocyte
# Successfully created the directory Lymphocyte
# 321
# Neutrophil
# Successfully created the directory Neutrophil
# 322
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22G-01Z-00-DX1_3
# 323
# Epithelial
# Successfully created the directory Epithelial
# 324
# Lymphocyte
# Successfully created the directory Lymphocyte
# 325
# Neutrophil
# Successfully created the directory Neutrophil
# 326
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E9-A22G-01Z-00-DX1_2
# 327
# Epithelial
# Successfully created the directory Epithelial
# 328
# Lymphocyte
# Successfully created the directory Lymphocyte
# 329
# Neutrophil
# Successfully created the directory Neutrophil
# 330
# Macrophage
# Successfully created the directory Macrophage
# TCGA-A2-A0CV-01Z-00-DX1
# /TCGA-A2-A0CV-01Z-00-DX1_4
# 331
# Epithelial
# Successfully created the directory Epithelial
# 332
# Lymphocyte
# Successfully created the directory Lymphocyte
# 333
# Neutrophil
# Successfully created the directory Neutrophil
# 334
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0CV-01Z-00-DX1_5
# 335
# Epithelial
# Successfully created the directory Epithelial
# 336
# Lymphocyte
# Successfully created the directory Lymphocyte
# 337
# Neutrophil
# Successfully created the directory Neutrophil
# 338
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0CV-01Z-00-DX1_2
# 339
# Epithelial
# Successfully created the directory Epithelial
# 340
# Lymphocyte
# Successfully created the directory Lymphocyte
# 341
# Neutrophil
# Successfully created the directory Neutrophil
# 342
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0CV-01Z-00-DX1_3
# 343
# Epithelial
# Successfully created the directory Epithelial
# 344
# Lymphocyte
# Successfully created the directory Lymphocyte
# 345
# Neutrophil
# Successfully created the directory Neutrophil
# 346
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-A2-A0CV-01Z-00-DX1_1
# 347
# Epithelial
# Successfully created the directory Epithelial
# 348
# Lymphocyte
# Successfully created the directory Lymphocyte
# 349
# Neutrophil
# Successfully created the directory Neutrophil
# 350
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A59X-01Z-00-DX1
# /TCGA-KK-A59X-01Z-00-DX1-1
# 351
# Epithelial
# Successfully created the directory Epithelial
# 352
# Lymphocyte
# Successfully created the directory Lymphocyte
# 353
# Neutrophil
# Successfully created the directory Neutrophil
# 354
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A59X-01Z-00-DX1-2
# 355
# Epithelial
# Successfully created the directory Epithelial
# 356
# Lymphocyte
# Successfully created the directory Lymphocyte
# 357
# Neutrophil
# Successfully created the directory Neutrophil
# 358
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-KK-A59X-01Z-00-DX1-3
# 359
# Epithelial
# Successfully created the directory Epithelial
# 360
# Lymphocyte
# Successfully created the directory Lymphocyte
# 361
# Neutrophil
# Successfully created the directory Neutrophil
# 362
# Macrophage
# Successfully created the directory Macrophage
# TCGA-J4-A67T-01Z-00-DX1
# /TCGA-J4-A67T-01Z-00-DX1-6
# 363
# Epithelial
# Successfully created the directory Epithelial
# 364
# Lymphocyte
# Successfully created the directory Lymphocyte
# 365
# Neutrophil
# Successfully created the directory Neutrophil
# 366
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67T-01Z-00-DX1-4
# 367
# Epithelial
# Successfully created the directory Epithelial
# 368
# Lymphocyte
# Successfully created the directory Lymphocyte
# 369
# Neutrophil
# Successfully created the directory Neutrophil
# 370
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67T-01Z-00-DX1-5
# 371
# Epithelial
# Successfully created the directory Epithelial
# 372
# Lymphocyte
# Successfully created the directory Lymphocyte
# 373
# Neutrophil
# Successfully created the directory Neutrophil
# 374
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67T-01Z-00-DX1-1
# 375
# Epithelial
# Successfully created the directory Epithelial
# 376
# Lymphocyte
# Successfully created the directory Lymphocyte
# 377
# Neutrophil
# Successfully created the directory Neutrophil
# 378
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67T-01Z-00-DX1-2
# 379
# Epithelial
# Successfully created the directory Epithelial
# 380
# Lymphocyte
# Successfully created the directory Lymphocyte
# 381
# Neutrophil
# Successfully created the directory Neutrophil
# 382
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-J4-A67T-01Z-00-DX1-3
# 383
# Epithelial
# Successfully created the directory Epithelial
# 384
# Lymphocyte
# Successfully created the directory Lymphocyte
# 385
# Neutrophil
# Successfully created the directory Neutrophil
# 386
# Macrophage
# Successfully created the directory Macrophage
# TCGA-69-A59K-01Z-00-DX1
# /TCGA-69-A59K-01Z-00-DX1_001
# 387
# Epithelial
# Successfully created the directory Epithelial
# 388
# Lymphocyte
# Successfully created the directory Lymphocyte
# 389
# Neutrophil
# Successfully created the directory Neutrophil
# 390
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-A59K-01Z-00-DX1_002
# 391
# Epithelial
# Successfully created the directory Epithelial
# 392
# Lymphocyte
# Successfully created the directory Lymphocyte
# 393
# Neutrophil
# Successfully created the directory Neutrophil
# 394
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-A59K-01Z-00-DX1_003
# 395
# Epithelial
# Successfully created the directory Epithelial
# 396
# Lymphocyte
# Successfully created the directory Lymphocyte
# 397
# Neutrophil
# Successfully created the directory Neutrophil
# 398
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-A59K-01Z-00-DX1_004
# 399
# Epithelial
# Successfully created the directory Epithelial
# 400
# Lymphocyte
# Successfully created the directory Lymphocyte
# 401
# Neutrophil
# Successfully created the directory Neutrophil
# 402
# Macrophage
# Successfully created the directory Macrophage
# TCGA-MH-A560-01Z-00-DX2
# /TCGA-MH-A560-01Z-00-DX2_4
# 403
# Epithelial
# Successfully created the directory Epithelial
# 404
# Lymphocyte
# Successfully created the directory Lymphocyte
# 405
# Neutrophil
# Successfully created the directory Neutrophil
# 406
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MH-A560-01Z-00-DX2_3
# 407
# Epithelial
# Successfully created the directory Epithelial
# 408
# Lymphocyte
# Successfully created the directory Lymphocyte
# 409
# Neutrophil
# Successfully created the directory Neutrophil
# 410
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MH-A560-01Z-00-DX2_2
# 411
# Epithelial
# Successfully created the directory Epithelial
# 412
# Lymphocyte
# Successfully created the directory Lymphocyte
# 413
# Neutrophil
# Successfully created the directory Neutrophil
# 414
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MH-A560-01Z-00-DX2_1
# 415
# Epithelial
# Successfully created the directory Epithelial
# 416
# Lymphocyte
# Successfully created the directory Lymphocyte
# 417
# Neutrophil
# Successfully created the directory Neutrophil
# 418
# Macrophage
# Successfully created the directory Macrophage
# TCGA-UZ-A9PO-01Z-00-DX1
# /TCGA-UZ-A9PO-01Z-00-DX1_5
# 419
# Epithelial
# Successfully created the directory Epithelial
# 420
# Lymphocyte
# Successfully created the directory Lymphocyte
# 421
# Neutrophil
# Successfully created the directory Neutrophil
# 422
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_4
# 423
# Epithelial
# Successfully created the directory Epithelial
# 424
# Lymphocyte
# Successfully created the directory Lymphocyte
# 425
# Neutrophil
# Successfully created the directory Neutrophil
# 426
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_6
# 427
# Epithelial
# Successfully created the directory Epithelial
# 428
# Lymphocyte
# Successfully created the directory Lymphocyte
# 429
# Neutrophil
# Successfully created the directory Neutrophil
# 430
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_7
# 431
# Epithelial
# Successfully created the directory Epithelial
# 432
# Lymphocyte
# Successfully created the directory Lymphocyte
# 433
# Neutrophil
# Successfully created the directory Neutrophil
# 434
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_3
# 435
# Epithelial
# Successfully created the directory Epithelial
# 436
# Lymphocyte
# Successfully created the directory Lymphocyte
# 437
# Neutrophil
# Successfully created the directory Neutrophil
# 438
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_2
# 439
# Epithelial
# Successfully created the directory Epithelial
# 440
# Lymphocyte
# Successfully created the directory Lymphocyte
# 441
# Neutrophil
# Successfully created the directory Neutrophil
# 442
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-UZ-A9PO-01Z-00-DX1_1
# 443
# Epithelial
# Successfully created the directory Epithelial
# 444
# Lymphocyte
# Successfully created the directory Lymphocyte
# 445
# Neutrophil
# Successfully created the directory Neutrophil
# 446
# Macrophage
# Successfully created the directory Macrophage
# TCGA-G9-6499-01Z-00-DX1
# /TCGA-G9-6499-01Z-00-DX1-1
# 447
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G9-6499-01Z-00-DX1-2
# 448
# Lymphocyte
# Successfully created the directory Lymphocyte
# /TCGA-G9-6499-01Z-00-DX1-3
# 449
# Lymphocyte
# Successfully created the directory Lymphocyte
# 450
# Neutrophil
# Successfully created the directory Neutrophil
# /TCGA-G9-6499-01Z-00-DX1-4
# 451
# Epithelial
# Successfully created the directory Epithelial
# 452
# Lymphocyte
# Successfully created the directory Lymphocyte
# /TCGA-G9-6499-01Z-00-DX1-5
# 453
# Lymphocyte
# Successfully created the directory Lymphocyte
# 454
# Epithelial
# Successfully created the directory Epithelial
# TCGA-P4-AAVK-01Z-00-DX1
# /TCGA-P4-AAVK-01Z-00-DX1_7
# 455
# Epithelial
# Successfully created the directory Epithelial
# 456
# Lymphocyte
# Successfully created the directory Lymphocyte
# 457
# Neutrophil
# Successfully created the directory Neutrophil
# 458
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_6
# 459
# Epithelial
# Successfully created the directory Epithelial
# 460
# Lymphocyte
# Successfully created the directory Lymphocyte
# 461
# Neutrophil
# Successfully created the directory Neutrophil
# 462
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_4
# 463
# Epithelial
# Successfully created the directory Epithelial
# 464
# Lymphocyte
# Successfully created the directory Lymphocyte
# 465
# Neutrophil
# Successfully created the directory Neutrophil
# 466
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_5
# 467
# Epithelial
# Successfully created the directory Epithelial
# 468
# Lymphocyte
# Successfully created the directory Lymphocyte
# 469
# Neutrophil
# Successfully created the directory Neutrophil
# 470
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_1
# 471
# Epithelial
# Successfully created the directory Epithelial
# 472
# Lymphocyte
# Successfully created the directory Lymphocyte
# 473
# Neutrophil
# Successfully created the directory Neutrophil
# 474
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_2
# 475
# Epithelial
# Successfully created the directory Epithelial
# 476
# Lymphocyte
# Successfully created the directory Lymphocyte
# 477
# Neutrophil
# Successfully created the directory Neutrophil
# 478
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-P4-AAVK-01Z-00-DX1_3
# 479
# Epithelial
# Successfully created the directory Epithelial
# 480
# Lymphocyte
# Successfully created the directory Lymphocyte
# 481
# Neutrophil
# Successfully created the directory Neutrophil
# 482
# Macrophage
# Successfully created the directory Macrophage
# TCGA-BH-A18T-01Z-00-DX1
# /TCGA-BH-A18T-01Z-00-DX1_1
# 483
# Epithelial
# Successfully created the directory Epithelial
# 484
# Lymphocyte
# Successfully created the directory Lymphocyte
# 485
# Neutrophil
# Successfully created the directory Neutrophil
# 486
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-BH-A18T-01Z-00-DX1_3
# 487
# Epithelial
# Successfully created the directory Epithelial
# 488
# Lymphocyte
# Successfully created the directory Lymphocyte
# 489
# Neutrophil
# Successfully created the directory Neutrophil
# 490
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-BH-A18T-01Z-00-DX1_2
# 491
# Epithelial
# Successfully created the directory Epithelial
# 492
# Lymphocyte
# Successfully created the directory Lymphocyte
# 493
# Neutrophil
# Successfully created the directory Neutrophil
# 494
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-BH-A18T-01Z-00-DX1_6
# 495
# Epithelial
# Successfully created the directory Epithelial
# 496
# Lymphocyte
# Successfully created the directory Lymphocyte
# 497
# Neutrophil
# Successfully created the directory Neutrophil
# 498
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-BH-A18T-01Z-00-DX1_5
# 499
# Epithelial
# Successfully created the directory Epithelial
# 500
# Lymphocyte
# Successfully created the directory Lymphocyte
# 501
# Neutrophil
# Successfully created the directory Neutrophil
# 502
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-BH-A18T-01Z-00-DX1_4
# 503
# Epithelial
# Successfully created the directory Epithelial
# 504
# Lymphocyte
# Successfully created the directory Lymphocyte
# 505
# Neutrophil
# Successfully created the directory Neutrophil
# 506
# Macrophage
# Successfully created the directory Macrophage
# TCGA-69-7760-01Z-00-DX1
# /TCGA-69-7760-01Z-00-DX1_004
# 507
# Epithelial
# Successfully created the directory Epithelial
# 508
# Lymphocyte
# Successfully created the directory Lymphocyte
# 509
# Neutrophil
# Successfully created the directory Neutrophil
# 510
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-7760-01Z-00-DX1_003
# 511
# Epithelial
# Successfully created the directory Epithelial
# 512
# Lymphocyte
# Successfully created the directory Lymphocyte
# 513
# Neutrophil
# Successfully created the directory Neutrophil
# 514
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-7760-01Z-00-DX1_002
# 515
# Epithelial
# Successfully created the directory Epithelial
# 516
# Lymphocyte
# Successfully created the directory Lymphocyte
# 517
# Neutrophil
# Successfully created the directory Neutrophil
# 518
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-69-7760-01Z-00-DX1_001
# 519
# Epithelial
# Successfully created the directory Epithelial
# 520
# Lymphocyte
# Successfully created the directory Lymphocyte
# 521
# Neutrophil
# Successfully created the directory Neutrophil
# 522
# Macrophage
# Successfully created the directory Macrophage
# TCGA-86-8672-01Z-00-DX1
# /TCGA-86-8672-01Z-00-DX1_3
# 523
# Epithelial
# Successfully created the directory Epithelial
# 524
# Lymphocyte
# Successfully created the directory Lymphocyte
# 525
# Neutrophil
# Successfully created the directory Neutrophil
# 526
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-86-8672-01Z-00-DX1_2
# 527
# Epithelial
# Successfully created the directory Epithelial
# 528
# Lymphocyte
# Successfully created the directory Lymphocyte
# 529
# Neutrophil
# Successfully created the directory Neutrophil
# 530
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-86-8672-01Z-00-DX1_1
# 531
# Epithelial
# Successfully created the directory Epithelial
# 532
# Lymphocyte
# Successfully created the directory Lymphocyte
# 533
# Neutrophil
# Successfully created the directory Neutrophil
# 534
# Macrophage
# Successfully created the directory Macrophage
# TCGA-MP-A4SY-01Z-00-DX1
# /TCGA-MP-A4SY-01Z-00-DX1_4
# 535
# Epithelial
# Successfully created the directory Epithelial
# 536
# Lymphocyte
# Successfully created the directory Lymphocyte
# 537
# Neutrophil
# Successfully created the directory Neutrophil
# 538
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4SY-01Z-00-DX1_1
# 539
# Epithelial
# Successfully created the directory Epithelial
# 540
# Lymphocyte
# Successfully created the directory Lymphocyte
# 541
# Neutrophil
# Successfully created the directory Neutrophil
# 542
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4SY-01Z-00-DX1_3
# 543
# Epithelial
# Successfully created the directory Epithelial
# 544
# Lymphocyte
# Successfully created the directory Lymphocyte
# 545
# Neutrophil
# Successfully created the directory Neutrophil
# 546
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4SY-01Z-00-DX1_2
# 547
# Epithelial
# Successfully created the directory Epithelial
# 548
# Lymphocyte
# Successfully created the directory Lymphocyte
# 549
# Neutrophil
# Successfully created the directory Neutrophil
# 550
# Macrophage
# Successfully created the directory Macrophage
# TCGA-MP-A4T7-01Z-00-DX1
# /TCGA-MP-A4T7-01Z-00-DX1_1
# 551
# Epithelial
# Successfully created the directory Epithelial
# 552
# Lymphocyte
# Successfully created the directory Lymphocyte
# 553
# Neutrophil
# Successfully created the directory Neutrophil
# 554
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4T7-01Z-00-DX1_2
# 555
# Epithelial
# Successfully created the directory Epithelial
# 556
# Lymphocyte
# Successfully created the directory Lymphocyte
# 557
# Neutrophil
# Successfully created the directory Neutrophil
# 558
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4T7-01Z-00-DX1_3
# 559
# Epithelial
# Successfully created the directory Epithelial
# 560
# Lymphocyte
# Successfully created the directory Lymphocyte
# 561
# Neutrophil
# Successfully created the directory Neutrophil
# 562
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-MP-A4T7-01Z-00-DX1_4
# 563
# Epithelial
# Successfully created the directory Epithelial
# 564
# Lymphocyte
# Successfully created the directory Lymphocyte
# 565
# Neutrophil
# Successfully created the directory Neutrophil
# 566
# Macrophage
# Successfully created the directory Macrophage
# TCGA-KK-A7AW-01Z-00-DX1
# /TCGA-KK-A7AW-01Z-00-DX1-1
# 567
# Epithelial
# Successfully created the directory Epithelial
# 568
# Lymphocyte
# Successfully created the directory Lymphocyte
# 569
# Neutrophil
# Successfully created the directory Neutrophil
# 570
# Macrophage
# Successfully created the directory Macrophage
# TCGA-E2-A154-01Z-00-DX1
# /TCGA-E2-A154-01Z-00-DX1_8
# 571
# Epithelial
# Successfully created the directory Epithelial
# 572
# Lymphocyte
# Successfully created the directory Lymphocyte
# 573
# Neutrophil
# Successfully created the directory Neutrophil
# 574
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_3
# 575
# Epithelial
# Successfully created the directory Epithelial
# 576
# Lymphocyte
# Successfully created the directory Lymphocyte
# 577
# Neutrophil
# Successfully created the directory Neutrophil
# 578
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_2
# 579
# Epithelial
# Successfully created the directory Epithelial
# 580
# Lymphocyte
# Successfully created the directory Lymphocyte
# 581
# Neutrophil
# Successfully created the directory Neutrophil
# 582
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_1
# 583
# Epithelial
# Successfully created the directory Epithelial
# 584
# Lymphocyte
# Successfully created the directory Lymphocyte
# 585
# Neutrophil
# Successfully created the directory Neutrophil
# 586
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_5
# 587
# Epithelial
# Successfully created the directory Epithelial
# 588
# Lymphocyte
# Successfully created the directory Lymphocyte
# 589
# Neutrophil
# Successfully created the directory Neutrophil
# 590
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_4
# 591
# Epithelial
# Successfully created the directory Epithelial
# 592
# Lymphocyte
# Successfully created the directory Lymphocyte
# 593
# Neutrophil
# Successfully created the directory Neutrophil
# 594
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_6
# 595
# Epithelial
# Successfully created the directory Epithelial
# 596
# Lymphocyte
# Successfully created the directory Lymphocyte
# 597
# Neutrophil
# Successfully created the directory Neutrophil
# 598
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-E2-A154-01Z-00-DX1_7
# 599
# Epithelial
# Successfully created the directory Epithelial
# 600
# Lymphocyte
# Successfully created the directory Lymphocyte
# 601
# Neutrophil
# Successfully created the directory Neutrophil
# 602
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EJ-5505-01Z-00-DX1
# /TCGA-EJ-5505-01Z-00-DX1-6
# 603
# Epithelial
# Successfully created the directory Epithelial
# 604
# Lymphocyte
# Successfully created the directory Lymphocyte
# 605
# Neutrophil
# Successfully created the directory Neutrophil
# 606
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5505-01Z-00-DX1-5
# 607
# Epithelial
# Successfully created the directory Epithelial
# 608
# Lymphocyte
# Successfully created the directory Lymphocyte
# 609
# Neutrophil
# Successfully created the directory Neutrophil
# 610
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5505-01Z-00-DX1-4
# 611
# Epithelial
# Successfully created the directory Epithelial
# 612
# Lymphocyte
# Successfully created the directory Lymphocyte
# 613
# Neutrophil
# Successfully created the directory Neutrophil
# 614
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5505-01Z-00-DX1-1
# 615
# Epithelial
# Successfully created the directory Epithelial
# 616
# Lymphocyte
# Successfully created the directory Lymphocyte
# 617
# Neutrophil
# Successfully created the directory Neutrophil
# 618
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5505-01Z-00-DX1-3
# 619
# Epithelial
# Successfully created the directory Epithelial
# 620
# Lymphocyte
# Successfully created the directory Lymphocyte
# 621
# Neutrophil
# Successfully created the directory Neutrophil
# 622
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5505-01Z-00-DX1-2
# 623
# Epithelial
# Successfully created the directory Epithelial
# 624
# Lymphocyte
# Successfully created the directory Lymphocyte
# 625
# Neutrophil
# Successfully created the directory Neutrophil
# 626
# Macrophage
# Successfully created the directory Macrophage
# TCGA-SX-A7SR-01Z-00-DX1
# /TCGA-SX-A7SR-01Z-00-DX1_1
# 627
# Epithelial
# Successfully created the directory Epithelial
# 628
# Lymphocyte
# Successfully created the directory Lymphocyte
# 629
# Neutrophil
# Successfully created the directory Neutrophil
# 630
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-SX-A7SR-01Z-00-DX1_2
# 631
# Epithelial
# Successfully created the directory Epithelial
# 632
# Lymphocyte
# Successfully created the directory Lymphocyte
# 633
# Neutrophil
# Successfully created the directory Neutrophil
# 634
# Macrophage
# Successfully created the directory Macrophage
# TCGA-V1-A9O9-01Z-00-DX1
# /TCGA-V1-A9O9-01Z-00-DX1-5
# 635
# Epithelial
# Successfully created the directory Epithelial
# 636
# Lymphocyte
# Successfully created the directory Lymphocyte
# 637
# Neutrophil
# Successfully created the directory Neutrophil
# 638
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-V1-A9O9-01Z-00-DX1-4
# 639
# Epithelial
# Successfully created the directory Epithelial
# 640
# Lymphocyte
# Successfully created the directory Lymphocyte
# 641
# Neutrophil
# Successfully created the directory Neutrophil
# 642
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-V1-A9O9-01Z-00-DX1-1
# 643
# Lymphocyte
# Successfully created the directory Lymphocyte
# 644
# Neutrophil
# Successfully created the directory Neutrophil
# 645
# Macrophage
# Successfully created the directory Macrophage
# 646
# Epithelial
# Successfully created the directory Epithelial
# /TCGA-V1-A9O9-01Z-00-DX1-3
# 647
# Epithelial
# Successfully created the directory Epithelial
# 648
# Lymphocyte
# Successfully created the directory Lymphocyte
# 649
# Neutrophil
# Successfully created the directory Neutrophil
# 650
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-V1-A9O9-01Z-00-DX1-2
# 651
# Epithelial
# Successfully created the directory Epithelial
# 652
# Lymphocyte
# Successfully created the directory Lymphocyte
# 653
# Neutrophil
# Successfully created the directory Neutrophil
# 654
# Macrophage
# Successfully created the directory Macrophage
# TCGA-B9-A44B-01Z-00-DX1
# /TCGA-B9-A44B-01Z-00-DX1_1
# 655
# Epithelial
# Successfully created the directory Epithelial
# 656
# Lymphocyte
# Successfully created the directory Lymphocyte
# 657
# Neutrophil
# Successfully created the directory Neutrophil
# 658
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A44B-01Z-00-DX1_3
# 659
# Epithelial
# Successfully created the directory Epithelial
# 660
# Lymphocyte
# Successfully created the directory Lymphocyte
# 661
# Neutrophil
# Successfully created the directory Neutrophil
# 662
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-B9-A44B-01Z-00-DX1_2
# 663
# Epithelial
# Successfully created the directory Epithelial
# 664
# Lymphocyte
# Successfully created the directory Lymphocyte
# 665
# Neutrophil
# Successfully created the directory Neutrophil
# 666
# Macrophage
# Successfully created the directory Macrophage
# TCGA-X4-A8KQ-01Z-00-DX8
# /TCGA-X4-A8KQ-01Z-00-DX8-3
# 667
# Epithelial
# Successfully created the directory Epithelial
# 668
# Lymphocyte
# Successfully created the directory Lymphocyte
# 669
# Neutrophil
# Successfully created the directory Neutrophil
# 670
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-X4-A8KQ-01Z-00-DX8-2
# 671
# Epithelial
# Successfully created the directory Epithelial
# 672
# Lymphocyte
# Successfully created the directory Lymphocyte
# 673
# Neutrophil
# Successfully created the directory Neutrophil
# 674
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-X4-A8KQ-01Z-00-DX8-1
# 675
# Epithelial
# Successfully created the directory Epithelial
# 676
# Lymphocyte
# Successfully created the directory Lymphocyte
# 677
# Neutrophil
# Successfully created the directory Neutrophil
# 678
# Macrophage
# Successfully created the directory Macrophage
# TCGA-V1-A8WL-01Z-00-DX1
# /TCGA-V1-A8WL-01Z-00-DX1-1
# 679
# Epithelial
# Successfully created the directory Epithelial
# 680
# Lymphocyte
# Successfully created the directory Lymphocyte
# 681
# Neutrophil
# Successfully created the directory Neutrophil
# 682
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-V1-A8WL-01Z-00-DX1-3
# 683
# Epithelial
# Successfully created the directory Epithelial
# 684
# Lymphocyte
# Successfully created the directory Lymphocyte
# 685
# Neutrophil
# Successfully created the directory Neutrophil
# 686
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-V1-A8WL-01Z-00-DX1-2
# 687
# Epithelial
# Successfully created the directory Epithelial
# 688
# Lymphocyte
# Successfully created the directory Lymphocyte
# 689
# Neutrophil
# Successfully created the directory Neutrophil
# 690
# Macrophage
# Successfully created the directory Macrophage
# TCGA-F9-A97G-01Z-00-DX1
# /TCGA-F9-A97G-01Z-00-DX1_4
# 691
# Epithelial
# Successfully created the directory Epithelial
# 692
# Lymphocyte
# Successfully created the directory Lymphocyte
# 693
# Neutrophil
# Successfully created the directory Neutrophil
# 694
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-F9-A97G-01Z-00-DX1_3
# 695
# Epithelial
# Successfully created the directory Epithelial
# 696
# Lymphocyte
# Successfully created the directory Lymphocyte
# 697
# Neutrophil
# Successfully created the directory Neutrophil
# 698
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-F9-A97G-01Z-00-DX1_2
# 699
# Epithelial
# Successfully created the directory Epithelial
# 700
# Lymphocyte
# Successfully created the directory Lymphocyte
# 701
# Neutrophil
# Successfully created the directory Neutrophil
# 702
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-F9-A97G-01Z-00-DX1_1
# 703
# Epithelial
# Successfully created the directory Epithelial
# 704
# Lymphocyte
# Successfully created the directory Lymphocyte
# 705
# Neutrophil
# Successfully created the directory Neutrophil
# 706
# Macrophage
# Successfully created the directory Macrophage
# TCGA-5P-A9K0-01Z-00-DX1
# /TCGA-5P-A9K0-01Z-00-DX1_1
# 707
# Epithelial
# Successfully created the directory Epithelial
# 708
# Lymphocyte
# Successfully created the directory Lymphocyte
# 709
# Neutrophil
# Successfully created the directory Neutrophil
# 710
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-5P-A9K0-01Z-00-DX1_3
# 711
# Epithelial
# Successfully created the directory Epithelial
# 712
# Lymphocyte
# Successfully created the directory Lymphocyte
# 713
# Neutrophil
# Successfully created the directory Neutrophil
# 714
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-5P-A9K0-01Z-00-DX1_2
# 715
# Epithelial
# Successfully created the directory Epithelial
# 716
# Lymphocyte
# Successfully created the directory Lymphocyte
# 717
# Neutrophil
# Successfully created the directory Neutrophil
# 718
# Macrophage
# Successfully created the directory Macrophage
# TCGA-78-7220-01Z-00-DX1
# /TCGA-78-7220-01Z-00-DX1_001
# 719
# Epithelial
# Successfully created the directory Epithelial
# 720
# Lymphocyte
# Successfully created the directory Lymphocyte
# 721
# Neutrophil
# Successfully created the directory Neutrophil
# 722
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-78-7220-01Z-00-DX1_003
# 723
# Epithelial
# Successfully created the directory Epithelial
# 724
# Lymphocyte
# Successfully created the directory Lymphocyte
# 725
# Neutrophil
# Successfully created the directory Neutrophil
# 726
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-78-7220-01Z-00-DX1_002
# 727
# Epithelial
# Successfully created the directory Epithelial
# 728
# Lymphocyte
# Successfully created the directory Lymphocyte
# 729
# Neutrophil
# Successfully created the directory Neutrophil
# 730
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-78-7220-01Z-00-DX1_004
# 731
# Epithelial
# Successfully created the directory Epithelial
# 732
# Lymphocyte
# Successfully created the directory Lymphocyte
# 733
# Neutrophil
# Successfully created the directory Neutrophil
# 734
# Macrophage
# Successfully created the directory Macrophage
# TCGA-G9-6342-01Z-00-DX1
# /TCGA-G9-6342-01Z-00-DX1-1
# 735
# Epithelial
# Successfully created the directory Epithelial
# 736
# Lymphocyte
# Successfully created the directory Lymphocyte
# 737
# Neutrophil
# Successfully created the directory Neutrophil
# 738
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-G9-6342-01Z-00-DX1-2
# 739
# Epithelial
# Successfully created the directory Epithelial
# 740
# Lymphocyte
# Successfully created the directory Lymphocyte
# 741
# Neutrophil
# Successfully created the directory Neutrophil
# 742
# Macrophage
# Successfully created the directory Macrophage
# TCGA-S3-AA11-01Z-00-DX1
# /TCGA-S3-AA11-01Z-00-DX1_6
# 743
# Epithelial
# Successfully created the directory Epithelial
# 744
# Lymphocyte
# Successfully created the directory Lymphocyte
# 745
# Neutrophil
# Successfully created the directory Neutrophil
# 746
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-S3-AA11-01Z-00-DX1_5
# 747
# Epithelial
# Successfully created the directory Epithelial
# 748
# Lymphocyte
# Successfully created the directory Lymphocyte
# 749
# Neutrophil
# Successfully created the directory Neutrophil
# 750
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-S3-AA11-01Z-00-DX1_4
# 751
# Epithelial
# Successfully created the directory Epithelial
# 752
# Lymphocyte
# Successfully created the directory Lymphocyte
# 753
# Neutrophil
# Successfully created the directory Neutrophil
# 754
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-S3-AA11-01Z-00-DX1_1
# 755
# Epithelial
# Successfully created the directory Epithelial
# 756
# Lymphocyte
# Successfully created the directory Lymphocyte
# 757
# Neutrophil
# Successfully created the directory Neutrophil
# 758
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-S3-AA11-01Z-00-DX1_3
# 759
# Epithelial
# Successfully created the directory Epithelial
# 760
# Lymphocyte
# Successfully created the directory Lymphocyte
# 761
# Neutrophil
# Successfully created the directory Neutrophil
# 762
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-S3-AA11-01Z-00-DX1_2
# 763
# Epithelial
# Successfully created the directory Epithelial
# 764
# Lymphocyte
# Successfully created the directory Lymphocyte
# 765
# Neutrophil
# Successfully created the directory Neutrophil
# 766
# Macrophage
# Successfully created the directory Macrophage
# TCGA-EJ-5495-01Z-00-DX1
# /TCGA-EJ-5495-01Z-00-DX1-4
# 767
# Epithelial
# Successfully created the directory Epithelial
# 768
# Lymphocyte
# Successfully created the directory Lymphocyte
# 769
# Neutrophil
# Successfully created the directory Neutrophil
# 770
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5495-01Z-00-DX1-2
# 771
# Epithelial
# Successfully created the directory Epithelial
# 772
# Lymphocyte
# Successfully created the directory Lymphocyte
# /TCGA-EJ-5495-01Z-00-DX1-3
# 773
# Epithelial
# Successfully created the directory Epithelial
# 774
# Lymphocyte
# Successfully created the directory Lymphocyte
# 775
# Neutrophil
# Successfully created the directory Neutrophil
# 776
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-EJ-5495-01Z-00-DX1-1
# 777
# Epithelial
# Successfully created the directory Epithelial
# 778
# Lymphocyte
# Successfully created the directory Lymphocyte
# TCGA-L4-A4E5-01Z-00-DX1
# /TCGA-L4-A4E5-01Z-00-DX1_1
# 779
# Epithelial
# Successfully created the directory Epithelial
# 780
# Lymphocyte
# Successfully created the directory Lymphocyte
# 781
# Neutrophil
# Successfully created the directory Neutrophil
# 782
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-L4-A4E5-01Z-00-DX1_2
# 783
# Epithelial
# Successfully created the directory Epithelial
# 784
# Lymphocyte
# Successfully created the directory Lymphocyte
# 785
# Neutrophil
# Successfully created the directory Neutrophil
# 786
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-L4-A4E5-01Z-00-DX1_3
# 787
# Epithelial
# Successfully created the directory Epithelial
# 788
# Lymphocyte
# Successfully created the directory Lymphocyte
# 789
# Neutrophil
# Successfully created the directory Neutrophil
# 790
# Macrophage
# Successfully created the directory Macrophage
# TCGA-86-7713-01Z-00-DX1
# /TCGA-86-7713-01Z-00-DX1_004
# 791
# Epithelial
# Successfully created the directory Epithelial
# 792
# Lymphocyte
# Successfully created the directory Lymphocyte
# 793
# Neutrophil
# Successfully created the directory Neutrophil
# 794
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-86-7713-01Z-00-DX1_003
# 795
# Epithelial
# Successfully created the directory Epithelial
# 796
# Lymphocyte
# Successfully created the directory Lymphocyte
# 797
# Neutrophil
# Successfully created the directory Neutrophil
# 798
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-86-7713-01Z-00-DX1_002
# 799
# Epithelial
# Successfully created the directory Epithelial
# 800
# Lymphocyte
# Successfully created the directory Lymphocyte
# 801
# Neutrophil
# Successfully created the directory Neutrophil
# 802
# Macrophage
# Successfully created the directory Macrophage
# /TCGA-86-7713-01Z-00-DX1_001
# 803
# Epithelial
# Successfully created the directory Epithelial
# 804
# Lymphocyte
# Successfully created the directory Lymphocyte
# 805
# Neutrophil
# Successfully created the directory Neutrophil
# 806
# Macrophage
# Successfully created the directory Macrophage

# %%
from shutil import copyfile
image_dest_path = MONUSAC_IMGS

for patient_loc in patients:
    images = glob(patient_loc+'/*.tif')
    for image in images:
        copyfile(image, image_dest_path + image.split('/').pop())

# %%
mask_dest_path = MONUSAC_MASKS

for idx, patient_loc in enumerate(patients):
    
    patient_name = patient_loc.split('/').pop()
    patient_folder = full_dest_path + patient_name
    sub_images = glob(patient_folder + '/*')
    
    for sub_image in sub_images: 
        result = np.empty([1, 1], dtype='uint8')
        mask_paths = [os.path.join(dp, f) for dp, dn, fn in os.walk(sub_image) for f in fn if f.endswith('.tif') and not dp.endswith('/Macrophage')]
        
        for mask_path in mask_paths:
            img = cv2.imread(mask_path)
            if result.shape == (1,1): 
                result = img
            else:
                result = result + img
        
        cv2.imwrite(mask_dest_path + '/' + sub_image.split('/').pop() + '.tif', result)
        
    print(str(idx) + ': ' + patient_name)
# Out:
# 0: TCGA-73-4668-01Z-00-DX1
# 1: TCGA-55-1594-01Z-00-DX1
# 2: TCGA-EV-5903-01Z-00-DX1
# 3: TCGA-YL-A9WY-01Z-00-DX1
# 4: TCGA-A2-A0ES-01Z-00-DX1
# 5: TCGA-DW-7841-01Z-00-DX1
# 6: TCGA-KK-A6E0-01Z-00-DX1
# 7: TCGA-UZ-A9PU-01Z-00-DX1
# 8: TCGA-B9-A8YI-01Z-00-DX1
# 9: TCGA-D8-A1X5-01Z-00-DX2
# 10: TCGA-EJ-5517-01Z-00-DX1
# 11: TCGA-J4-A67Q-01Z-00-DX1
# 12: TCGA-EW-A6SD-01Z-00-DX1
# 13: TCGA-E9-A22B-01Z-00-DX1
# 14: TCGA-G7-A8LD-01Z-00-DX1
# 15: TCGA-B6-A0WZ-01Z-00-DX1
# 16: TCGA-E9-A22G-01Z-00-DX1
# 17: TCGA-A2-A0CV-01Z-00-DX1
# 18: TCGA-KK-A59X-01Z-00-DX1
# 19: TCGA-J4-A67T-01Z-00-DX1
# 20: TCGA-69-A59K-01Z-00-DX1
# 21: TCGA-MH-A560-01Z-00-DX2
# 22: TCGA-UZ-A9PO-01Z-00-DX1
# 23: TCGA-G9-6499-01Z-00-DX1
# 24: TCGA-P4-AAVK-01Z-00-DX1
# 25: TCGA-BH-A18T-01Z-00-DX1
# 26: TCGA-69-7760-01Z-00-DX1
# 27: TCGA-86-8672-01Z-00-DX1
# 28: TCGA-MP-A4SY-01Z-00-DX1
# 29: TCGA-MP-A4T7-01Z-00-DX1
# 30: TCGA-KK-A7AW-01Z-00-DX1
# 31: TCGA-E2-A154-01Z-00-DX1
# 32: TCGA-EJ-5505-01Z-00-DX1
# 33: TCGA-SX-A7SR-01Z-00-DX1
# 34: TCGA-V1-A9O9-01Z-00-DX1
# 35: TCGA-B9-A44B-01Z-00-DX1
# 36: TCGA-X4-A8KQ-01Z-00-DX8
# 37: TCGA-V1-A8WL-01Z-00-DX1
# 38: TCGA-F9-A97G-01Z-00-DX1
# 39: TCGA-5P-A9K0-01Z-00-DX1
# 40: TCGA-78-7220-01Z-00-DX1
# 41: TCGA-G9-6342-01Z-00-DX1
# 42: TCGA-S3-AA11-01Z-00-DX1
# 43: TCGA-EJ-5495-01Z-00-DX1
# 44: TCGA-L4-A4E5-01Z-00-DX1
# 45: TCGA-86-7713-01Z-00-DX1
